# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

class DeepNeuralNetwork:
    def __init__(self,input_size,hidden_layers,output_size,task):
        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.output_size = output_size
        self.task = task
        self.model = self.build_model()

    def build_model(self):
        model = Sequential()
        model.add(Dense(self.hidden_layers[0],input_dim=self.input_size,activation ='relu'))

        for size in (self.hidden_layers[1:]):
            model.add(Dense(size,activation='relu'))

        if self.task=='classification':
            model.add(Dense(self.output_size,activation='softmax'))
            model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
        elif self.task=='regression':
            model.add(Dense(self.output_size,activation='linear'))
            model.compile(loss='mean_squared_error',optimizer='adam',metrics=['mse'])
        else:
            raise ValueError("Invalid Task. Use 'classification' or 'regression'")
        return model

    def train(self,X_train,y_train,epochs,batch_size):
        if self.task=='classification':
            y_train_categorical = np.eye(self.output_size)[y_train]
            self.model.fit(X_train,y_train_categorical,epochs=epochs,batch_size=batch_size)
        elif self.task=='regression':
            self.model.fit(X_train,y_train,epochs=epochs,batch_size=batch_size)

    def predict(self,X_test):
        return self.model.predict(X_test)

# %%
#======================Classification Usage ========================#
x_classification = np.array([[0,0],[0,1],[1,0],[1,1]])
y_classification = np.array([0,1,1,0])

input_size_classification = x_classification.shape[1]
hidden_layers =[4,3]
output_size_classification = len(np.unique(y_classification))
epochs = 100
batch_size =1

dnn_classification = DeepNeuralNetwork(
    input_size_classification,
    hidden_layers,
    output_size_classification,
    task='classification'
)

dnn_classification.train(x_classification,y_classification,epochs,batch_size)
test_input_classification = np.array([[0,0],[0,1],[1,0],[1,1]])
predicted_output_classification = dnn_classification.predict(test_input_classification)
print("Predicted Output Probabilites :\n",np.round(predicted_output_classification,3))
print("Predicted Classes :",np.argmax(predicted_output_classification,axis=1))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6333 - loss: 0.6531
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.1000 - loss: 0.6748
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4333 - loss: 0.6430
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7333 - loss: 0.5677
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6333 - loss: 0.5670
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6333 - loss: 0.5655
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3667 - loss: 0.6256
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5667 - loss: 0.5677
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6333 - loss: 0.6553
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2667 - loss: 0.6577
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.6180
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3667 - loss: 0.6815
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2667 - loss: 0.6628
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5667 - loss: 0.6706
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7333 - loss: 0.6151
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4333 - loss: 0.6481
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4333 - loss: 0.6282
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4333 - loss: 0.6186
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2667 - loss: 0.6729
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6333 - loss: 0.5597
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.6108
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4333 - loss: 0.6167
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5667 - loss: 0.6628
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5667 - loss: 0.6621
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2667 - loss: 0.6702
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4333 - loss: 0.6150
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2667 - loss: 0.6518
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5667 - loss: 0.6609
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2667 - loss: 0.6691
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3667 - loss: 0.6154
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3667 - loss: 0.6147
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.5428
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4333 - loss: 0.6407
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3667 - loss: 0.6609
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6333 - loss: 0.5437
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4333 - loss: 0.6400
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5667 - loss: 0.6532
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4333 - loss: 0.6037
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.6021
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6097
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.5388
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5333 - loss: 0.6408
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.5933
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6068
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.5983
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.5967
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7333 - loss: 0.5317
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6029
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8333 - loss: 0.6456
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.5226
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9000 - loss: 0.6186
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6355
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.6174
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.6388
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6001
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.6253
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7333 - loss: 0.6247
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5333 - loss: 0.6332
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.6236
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9000 - loss: 0.5744
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.5133
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8333 - loss: 0.5759
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.5714
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.5761
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7333 - loss: 0.5126
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.6316
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6269
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9000 - loss: 0.5016
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9000 - loss: 0.4997
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.5707
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.4970
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.5895
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8333 - loss: 0.6273
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.4987
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9000 - loss: 0.5971
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.5877
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.6304
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.5570
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6256
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.6294
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.4953
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.6356
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7333 - loss: 0.6011
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5333 - loss: 0.6453
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.6194
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.6096
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5333 - loss: 0.6179
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5333 - loss: 0.5825
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6435
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.5965
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.5900
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6428
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5333 - loss: 0.6208
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.5936
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.6453
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8333 - loss: 0.6123
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7333 - loss: 0.4790
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.5906
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9000 - loss: 0.4596
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8333 - loss: 0.4635
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Predicted Output Probabilites :
#  [[0.539 0.461]
#  [0.52  0.48 ]
#  [0.209 0.791]
#  [0.52  0.48 ]]
# Predicted Classes : [0 0 1 0]

# %%
#=====================Regression Usage ============================#
x_regression = np.array([[1],[2],[3],[4],[5]])
y_regression = np.array([[2],[4],[6],[8],[10]])

input_size_regression = x_regression.shape[1]
output_size_regression = 1

dnn_regression = DeepNeuralNetwork(
    input_size_regression,
    hidden_layers,
    output_size_regression,
    task='regression'
)
dnn_regression.train(x_regression,y_regression,epochs,batch_size)
test_input_regression = np.array([[6],[7]])
predicted_output_regression = dnn_regression.predict(test_input_regression)
print("Predicted Output :",np.round(predicted_output_regression,2))
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 60.1909 - mse: 60.1909
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 82.3982 - mse: 82.3982
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.3617 - mse: 40.3617
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 51.0570 - mse: 51.0570
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 59.8682 - mse: 59.8682
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.8868 - mse: 44.8868
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.6349 - mse: 40.6349
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 78.7358 - mse: 78.7358
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 72.1396 - mse: 72.1396
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 82.5460 - mse: 82.5460
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 69.8224 - mse: 69.8224
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 81.0223 - mse: 81.0223
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 72.4546 - mse: 72.4546
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 59.6977 - mse: 59.6977
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 48.9928 - mse: 48.9928
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 47.8868 - mse: 47.8868
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 71.8181 - mse: 71.8181
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 56.8692 - mse: 56.8692
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 72.3810 - mse: 72.3810
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 63.4389 - mse: 63.4389
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 36.6488 - mse: 36.6488
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 57.7106 - mse: 57.7106
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39.6535 - mse: 39.6535
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 49.6049 - mse: 49.6049
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.9782 - mse: 40.9782
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 45.3042 - mse: 45.3042
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 69.9186 - mse: 69.9186
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 59.0887 - mse: 59.0887
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.9204 - mse: 44.9204
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.6639 - mse: 43.6639
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.4397 - mse: 37.4397
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.3182 - mse: 35.3182
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 47.3239 - mse: 47.3239
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.9896 - mse: 34.9896
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.9273 - mse: 39.9273
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 50.7640 - mse: 50.7640
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 33.8410 - mse: 33.8410
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.6146 - mse: 26.6146
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.7631 - mse: 24.7631
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.2429 - mse: 33.2429
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 58.4719 - mse: 58.4719
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 38.7832 - mse: 38.7832
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 56.9230 - mse: 56.9230
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 51.6333 - mse: 51.6333
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 43.0373 - mse: 43.0373
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 26.6100 - mse: 26.6100
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 44.1859 - mse: 44.1859
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 33.5248 - mse: 33.5248
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 38.3268 - mse: 38.3268
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.8114 - mse: 23.8114
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.0379 - mse: 30.0379
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 40.7540 - mse: 40.7540
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 50.8224 - mse: 50.8224
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 56.3292 - mse: 56.3292
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 41.0250 - mse: 41.0250
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 38.3931 - mse: 38.3931
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.1632 - mse: 26.1632
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 49.0013 - mse: 49.0013
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.1274 - mse: 30.1274
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.9449 - mse: 22.9449
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 34.6735 - mse: 34.6735
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.2247 - mse: 30.2247
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.1930 - mse: 32.1930
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 50.9212 - mse: 50.9212
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.0391 - mse: 39.0391
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.2954 - mse: 33.2954
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.7331 - mse: 44.7331
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.9141 - mse: 24.9141
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 42.3268 - mse: 42.3268
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.8536 - mse: 23.8536
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32.9191 - mse: 32.9191
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.1965 - mse: 39.1965
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.9956 - mse: 26.9956
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.1437 - mse: 28.1437
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.8153 - mse: 21.8153
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.5225 - mse: 31.5225
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.9445 - mse: 28.9445
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.8907 - mse: 31.8907
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.7749 - mse: 24.7749
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.5662 - mse: 26.5662
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.7855 - mse: 30.7855
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.2233 - mse: 29.2233
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.8772 - mse: 18.8772
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.1179 - mse: 29.1179
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.2472 - mse: 21.2472
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.8104 - mse: 33.8104
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.5160 - mse: 23.5160
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.7885 - mse: 25.7885
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.2162 - mse: 32.2162
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.5642 - mse: 16.5642
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.3546 - mse: 31.3546
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.3067 - mse: 22.3067
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.0878 - mse: 16.0878
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.0020 - mse: 20.0020
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.4100 - mse: 18.4100
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.4731 - mse: 14.4731
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.4715 - mse: 12.4715
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.0314 - mse: 14.0314
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.4698 - mse: 16.4698
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.0623 - mse: 24.0623
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Predicted Output : [[3.86]
#  [4.37]]
